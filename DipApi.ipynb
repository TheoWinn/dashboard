# %%
import requests

BASE = "https://search.dip.bundestag.de/api/v1"
ID = "1"
API_KEY = "OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw"

url = f"{BASE}/vorgang"
headers = {"Authorization": f"ApiKey {API_KEY}"}

r = requests.get(url, headers=headers, timeout=30)
print(r.status_code)
print(r.json())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 19
#      16     params["cursor"] = cursor
#      18 r = requests.get(f"{BASE}/vorgang", headers=headers, params=params, timeout=30)
# ---> 19 r.raise_for_status()
#      20 data = r.json()
#      22 # Extract descriptors from each document
#
# File ~/semester3/Lab/dashboard/.venv/lib/python3.13/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://search.dip.bundestag.de/.enodia/challenge?redirect=%2Fapi%2Fv1%2Fvorgang%3Fsize%3D100
